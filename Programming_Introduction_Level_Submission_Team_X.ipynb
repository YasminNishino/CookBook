# %%
import os
import requests
from requests.exceptions import HTTPError, ConnectionError, Timeout

# Load API key from an environment variable or a configuration file
api_key = '989d6a73cdf14247b4bb64823437dd5e'

def get_recipe_information(recipe_id, api_key, include_nutrition=True):
    try:
        include_nutrition_str = 'true' if include_nutrition else 'false'
        info_url = f"https://api.spoonacular.com/recipes/{recipe_id}/information?includeNutrition={include_nutrition_str}&apiKey={api_key}"
        
        response = requests.get(info_url)
        response.raise_for_status()

        return response.json()
    
    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except Exception as err:
        print(f"An error occurred: {err}")

    return None

def get_recipes_by_ingredients(api_key):
    try:
        ingredients = input("Enter the ingredients you have available (separated by commas): ")
        find_url = f"https://api.spoonacular.com/recipes/findByIngredients?ingredients={ingredients}&number=5&apiKey={api_key}"
        
        response = requests.get(find_url)
        response.raise_for_status()

        return response.json()

    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except Exception as err:
        print(f"An error occurred: {err}")

    return None

# Ask the user if they want to include nutrition data
include_nutrition = input("Would you like to include nutrition data? (yes/no): ").lower() == 'yes'

# Fetch recipes based on user input
recipes = get_recipes_by_ingredients(api_key)

# Check if recipes were found
if recipes:
    print("\nHere are some recipes based on the ingredients you have:")
    
    for recipe in recipes:
        recipe_info = get_recipe_information(recipe['id'], api_key, include_nutrition)
        
        if recipe_info:
            print(f"\nRecipe: {recipe_info['title']}")
            print(f"Link: {recipe_info.get('sourceUrl', 'No URL available')}")
            print(f"Missing Ingredients: {', '.join([ingredient['name'] for ingredient in recipe['missedIngredients']])}")

            if include_nutrition and 'nutrition' in recipe_info:
                print("Nutritional Information (per serving):")
                for nutrient in recipe_info['nutrition']['nutrients']:
                    print(f"- {nutrient['name']}: {nutrient['amount']}{nutrient['unit']}")
            else:
                print("Nutritional information is not included.")
else:
    print("No recipes found. Please try different ingredients.")
# Out:
# Would you like to include nutrition data? (yes/no):  yes
# Enter the ingredients you have available (separated by commas):  pasta, olives, tuna
# Here are some recipes based on the ingredients you have:
#
# Recipe: Mummy Meatballs with Spaghetti
# Link: http://www.foodista.com/recipe/773WJ8V5/mummy-meatballs-with-spaghetti
# Missing Ingredients: bread crumbs, egg, garlic paste, seasoning, ground beef, parmesan cheese, spaghetti sauce
# Nutritional Information (per serving):
# - Calories: 530.63kcal
# - Fat: 8.91g
# - Saturated Fat: 2.27g
# - Carbohydrates: 88.61g
# - Net Carbohydrates: 83.19g
# - Sugar: 5.0g
# - Cholesterol: 77.6mg
# - Sodium: 876.61mg
# - Protein: 23.58g
# - Selenium: 87.44µg
# - Manganese: 1.12mg
# - Phosphorus: 336.6mg
# - Zinc: 3.61mg
# - Copper: 0.46mg
# - Vitamin B3: 4.56mg
# - Fiber: 5.42g
# - Magnesium: 82.45mg
# - Vitamin B6: 0.4mg
# - Iron: 3.42mg
# - Potassium: 562.43mg
# - Vitamin B12: 0.86µg
# - Vitamin B1: 0.21mg
# - Vitamin E: 2.03mg
# - Vitamin B2: 0.2mg
# - Vitamin B5: 1.2mg
# - Folate: 39.16µg
# - Vitamin A: 402.34IU
# - Calcium: 77.86mg
# - Vitamin C: 4.34mg
# - Vitamin K: 3.51µg
# - Vitamin D: 0.27µg
#
# Recipe: Macaroni Pasta with Fresh Tomatoes, Zucchini and Artichokes
# Link: http://www.foodista.com/recipe/GNWPCVW7/fresh-tomatoes-zucchini-and-artichokes-with-macaroni
# Missing Ingredients: artichokes, cloves of garlic - crushed&, oregano, parsley, pepper flakes, romano cheese, onion, vine tomatoes, zucchini
# Nutritional Information (per serving):
# - Calories: 783.97kcal
# - Fat: 29.2g
# - Saturated Fat: 8.2g
# - Carbohydrates: 99.84g
# - Net Carbohydrates: 90.92g
# - Sugar: 9.93g
# - Cholesterol: 38.64mg
# - Sodium: 973.6mg
# - Protein: 32.0g
# - Vitamin K: 145.04µg
# - Selenium: 88.04µg
# - Manganese: 1.44mg
# - Phosphorus: 572.66mg
# - Vitamin C: 39.3mg
# - Calcium: 421.31mg
# - Vitamin A: 1883.04IU
# - Fiber: 8.92g
# - Magnesium: 129.85mg
# - Copper: 0.58mg
# - Vitamin E: 4.32mg
# - Potassium: 936.74mg
# - Vitamin B6: 0.53mg
# - Folate: 94.49µg
# - Vitamin B3: 4.42mg
# - Zinc: 3.12mg
# - Iron: 3.72mg
# - Vitamin B2: 0.3mg
# - Vitamin B1: 0.23mg
# - Vitamin B5: 1.03mg
# - Vitamin B12: 0.54µg
# - Vitamin D: 0.5µg
#
# Recipe: Tuna Spaghetti With Fava Beans
# Link: http://www.foodista.com/recipe/8ZFSYNTB/tuna-spaghetti-with-fava-beans
# Missing Ingredients: broad beans, canned tomatoes, cayenne pepper, thyme, garlic, herbs, onion, oregano, parmesan, paprika, tomato puree, vegetable stock cube
# Nutritional Information (per serving):
# - Calories: 722.84kcal
# - Fat: 28.0g
# - Saturated Fat: 7.8g
# - Carbohydrates: 77.94g
# - Net Carbohydrates: 66.82g
# - Sugar: 15.54g
# - Cholesterol: 51.0mg
# - Sodium: 1984.68mg
# - Protein: 43.3g
# - Selenium: 103.13µg
# - Manganese: 1.85mg
# - Vitamin B3: 13.01mg
# - Phosphorus: 584.06mg
# - Calcium: 508.83mg
# - Fiber: 11.12g
# - Vitamin B12: 2.54µg
# - Vitamin B6: 0.82mg
# - Vitamin E: 6.08mg
# - Copper: 0.74mg
# - Iron: 6.63mg
# - Magnesium: 142.94mg
# - Potassium: 1232.24mg
# - Vitamin C: 24.82mg
# - Vitamin K: 24.82µg
# - Zinc: 3.42mg
# - Vitamin B2: 0.38mg
# - Vitamin A: 1097.15IU
# - Folate: 82.67µg
# - Vitamin B1: 0.29mg
# - Vitamin B5: 1.28mg
# - Vitamin D: 1.17µg
#
# Recipe: Eyeballs Fettuccine
# Link: https://www.foodista.com/recipe/H6FVWWTT/eyeballs-fettuccine
# Missing Ingredients: cheesy meatballs, prego tomato pasta sauce, baby asparagus, some capsicum, egg
# Nutritional Information (per serving):
# - Calories: 301.01kcal
# - Fat: 20.8g
# - Saturated Fat: 6.54g
# - Carbohydrates: 11.84g
# - Net Carbohydrates: 8.08g
# - Sugar: 7.36g
# - Cholesterol: 227.66mg
# - Sodium: 879.01mg
# - Protein: 18.03g
# - Vitamin C: 102.8mg
# - Vitamin A: 3107.4IU
# - Selenium: 30.82µg
# - Vitamin B1: 0.51mg
# - Vitamin B2: 0.52mg
# - Vitamin B6: 0.6mg
# - Vitamin E: 3.89mg
# - Phosphorus: 233.65mg
# - Vitamin B3: 4.25mg
# - Potassium: 687.14mg
# - Folate: 69.06µg
# - Vitamin B5: 1.63mg
# - Vitamin B12: 0.95µg
# - Fiber: 3.76g
# - Zinc: 2.19mg
# - Iron: 2.48mg
# - Manganese: 0.22mg
# - Magnesium: 42.33mg
# - Copper: 0.19mg
# - Vitamin D: 1.1µg
# - Vitamin K: 6.93µg
# - Calcium: 62.76mg
#
# Recipe: Italian Tuna Pasta
# Link: http://www.foodista.com/recipe/4QNQXMDZ/italian-tuna-pasta
# Missing Ingredients: chillies, garlic, juice of lemon, parsley leaves, bell pepper
# Nutritional Information (per serving):
# - Calories: 463.7kcal
# - Fat: 2.91g
# - Saturated Fat: 0.59g
# - Carbohydrates: 70.33g
# - Net Carbohydrates: 65.91g
# - Sugar: 6.1g
# - Cholesterol: 48.0mg
# - Sodium: 307.56mg
# - Protein: 37.7g
# - Selenium: 143.67µg
# - Vitamin K: 170.7µg
# - Vitamin C: 115.76mg
# - Vitamin B3: 15.57mg
# - Vitamin B12: 3.43µg
# - Vitamin A: 2447.95IU
# - Manganese: 0.97mg
# - Vitamin B6: 0.86mg
# - Phosphorus: 375.02mg
# - Iron: 4.48mg
# - Magnesium: 93.53mg
# - Potassium: 688.82mg
# - Copper: 0.38mg
# - Fiber: 4.42g
# - Folate: 64.78µg
# - Zinc: 2.38mg
# - Vitamin B2: 0.23mg
# - Vitamin B1: 0.18mg
# - Vitamin D: 1.6µg
# - Vitamin E: 1.47mg
# - Vitamin B5: 0.83mg
# - Calcium: 68.75mg
